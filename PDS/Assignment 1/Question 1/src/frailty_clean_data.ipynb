# %% [markdown]
# Step 1: Data Collection

# %%
import os
import pandas as pd
# reading csv file by using inbuilt pandas function
df=pd.read_csv('/content/raw_frailty_data.csv')
df
# Out:
#    Height  Weight  Age  Grip strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y
# 5    68.7     123   50             26       N
# 6    69.8     141   51             22       Y
# 7    70.1     136   23             20       Y
# 8    67.9     112   17             19       N
# 9    66.8     120   39             31       N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Height         10 non-null     float64
#  1   Weight         10 non-null     int64
#  2   Age            10 non-null     int64
#  3   Grip strength  10 non-null     int64
#  4   Frailty        10 non-null     object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 528.0+ bytes

# %%
# description of the dataset which includes mean, standard deviation, min and max values of each attribute

df.describe()
# Out:
#           Height      Weight        Age  Grip strength
# count  10.000000   10.000000  10.000000      10.000000
# mean   68.600000  131.900000  32.500000      26.000000
# std     1.670662   14.231811  12.860361       4.521553
# min    65.800000  112.000000  17.000000      19.000000
# 25%    67.825000  120.750000  22.250000      22.500000
# 50%    68.450000  136.000000  29.500000      27.000000
# 75%    69.700000  141.750000  43.500000      29.750000
# max    71.500000  153.000000  51.000000      31.000000

# %% [markdown]
# Step 2: Data Preprocessing

# %%
# checking whether any attribute has null values
df.isnull().sum()
# Out:
# Height           0
# Weight           0
# Age              0
# Grip strength    0
# Frailty          0
# dtype: int64

# %%
#same as isnull function
df.isna()
# Out:
#    Height  Weight    Age  Grip strength  Frailty
# 0   False   False  False          False    False
# 1   False   False  False          False    False
# 2   False   False  False          False    False
# 3   False   False  False          False    False
# 4   False   False  False          False    False
# 5   False   False  False          False    False
# 6   False   False  False          False    False
# 7   False   False  False          False    False
# 8   False   False  False          False    False
# 9   False   False  False          False    False

# %%
# to check for any duplicated values
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
# exporting cleaned dataset to a specified location
df.to_csv('/content/cleaned_frailty_data.csv', index=False)
